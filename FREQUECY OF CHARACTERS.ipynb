# %% [markdown]
# # Program to find frequency of each character

# %%
a=input("enter any string")
b=input("search character")
c=0

for i in a:
    if i==b:
        c=c+1
print("frequency of character=",c)
# Out:
# enter any stringhello world
# search characterl
# frequency of character= 3
