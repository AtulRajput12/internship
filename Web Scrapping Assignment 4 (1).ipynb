# %% [markdown]
# # Q1.. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome(r'C:\Users\ankus\Downloads\chromedriver_win32 (1)\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
table=[]
for i in driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]'):
    table.append(i.text.replace('\n'," "))
table
# Out:
# ['Top 30 most-viewed YouTube videos[2] No. Video name Uploader Views (billions) Upload date Note 1. "Baby Shark Dance"[3] Pinkfong Baby Shark - Kids\' Songs & Stories 10.25 June 17, 2016 [B] 2. "Despacito"[6] Luis Fonsi 7.76 January 12, 2017 [C] 3. "Johny Johny Yes Papa"[12] LooLoo Kids 6.20 October 8, 2016 [D] 4. "Shape of You"[13] Ed Sheeran 5.63 January 30, 2017 [E] 5. "See You Again"[15] Wiz Khalifa 5.43 April 6, 2015 [F] 6. "Bath Song"[20] Cocomelon – Nursery Rhymes 5.03 May 2, 2018 [G] 7. "Learning Colors – Colorful Eggs on a Farm"[21] Miroshka TV 4.56 February 27, 2018 [H] 8. "Phonics Song with Two Words"[22] ChuChu TV 4.49 March 6, 2014 [I] 9. "Masha and the Bear – Recipe for Disaster"[23] Get Movies 4.49 January 31, 2012 [J] 10. "Uptown Funk"[24] Mark Ronson 4.47 November 19, 2014 [K] 11. "Gangnam Style"[25] Psy 4.35 July 15, 2012 [L] 12. "Dame Tu Cosita"[30] El Chombo 3.87 April 5, 2018 13. "Wheels on the Bus"[31] Cocomelon – Nursery Rhymes 3.72 May 24, 2018 14. "Sugar"[32]
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get("https://www.bcci.tv/.")

# %%
int_button=driver.find_element_by_xpath('/html/body/nav/div/div[2]/ul[1]/li[2]/a')
int_button.click()

# %%
fixtures_tag=driver.find_element_by_xpath('//button[@class="match-btn btn-red d-flex align-items-center justify-content-center mx-auto mt-3"]')
fixtures_tag.click()

# %%
Series=[]
for i in driver.find_elements_by_xpath('//span[@class="ng-binding"]'):
    Series.append(i.text)
len(Series)
# Out:
# 16

# %%
Match=[]
for i in driver.find_elements_by_xpath('//div[@class="fixture-card-bottom"]'):
    Match.append(i.text)
len(Match)
# Out:
# 16

# %%
Date=[]
for i in driver.find_elements_by_xpath('//h5[@class="ng-binding"]'):
    Date.append(i.text)
len(Date)
# Out:
# 16

# %%
Time=[]
for i in driver.find_elements_by_xpath('//h5[@class="text-right ng-binding"]'):
    Time.append(i.text)
len(Time)
# Out:
# 16

# %%
data=pd.DataFrame()
data['Series']=Series
data['Match']=Match
data['Date']=Date
data['Time']=Time
data
# Out:
#                                         Series  \
# 0      SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 1      SRI LANKA TOUR OF INDIA T20 SERIES 2022
# 2     SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 3                    ICC WOMENS WORLD CUP 2022
# 4                    ICC WOMENS WORLD CUP 2022
# 5     SRI LANKA TOUR OF INDIA TEST SERIES 2022
# 6                    ICC WOMENS WORLD CUP 2022
# 7                    ICC WOMENS WORLD CUP 2022
# 8                    ICC WOMENS WORLD CUP 2022
# 9                    ICC WOMENS WORLD CUP 2022
# 10                   ICC WOMENS WORLD CUP 2022
# 11  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 12  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 13  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 14  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
# 15  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022
#
#                                                 Match         Date  \
# 0   2nd T20I - Himachal Pradesh Cricket Associatio...  26 FEB 2022
# ...

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get("https://www.guru99.com/")

# %%
#wait for few seconds before this step
search_bar=driver.find_element_by_xpath('//input[@class="gsc-input"]')
search_bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6e2a0606ac6f46437058dbb1268c01ca", element="f98600ea-0afe-4f7e-8874-7efa081c91e9")>

# %%
search_bar.send_keys("selenium exception handling")

# %%
search_button=driver.find_element_by_xpath('//button[@class="gsc-search-button gsc-search-button-v2"]')
search_button.click()

# %%
#scrool down the webpage little brfore run this line of code
list=driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/div[1]/div[6]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a/b')
list.click()

# %%
table=[]
for i in driver.find_elements_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table/tbody'):
    table.append(i.text)
table
# Out:
# []

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get(" http://statisticstimes.com/")

# %%
#create empty list
Rank=[]
State=[]
GSDP1=[]
GSDP2=[]
Share=[]
GDP=[]

# %%
economy=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')
economy.click()

# %%
india=driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
india.click()

# %%
#if there is add then close it manually
gdp_tag=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
gdp_tag.click()

# %%
for i in driver.find_elements_by_xpath('//td[@class="data1"]'):
    Rank.append(i.text)
Rank=Rank[:33]

# %%
for i in driver.find_elements_by_xpath('//td[@class="name"]'):
    State.append(i.text)
State=State[:33]

# %%
tag=[]
for i in driver.find_elements_by_xpath('//td[@class="data"]'):
    tag.append(i.text)
tag
# Out:
# ['-',
#  '13.94%',
#  '399.921',
#  '-',
#  '2,039,074',
#  '1,845,853',
#  '8.63%',
#  '247.629',
#  '1,312,929',
#  '1,215,307',
#  '1,687,818',
#  '8.39%',
#  '240.726',
#  '1,166,817',
#  '1,123,982',
#  '-',
#  '7.96%',
#  '228.290',
#  '-',
#  '1,186,379',
#  '1,631,977',
#  '7.91%',
#  '226.806',
#  '1,156,039',
#  '1,091,077',
#  '1,253,832',
#  '5.77%',
#  '165.556',
#  '793,223',
#  '739,525',
#  '1,020,989',
#  '4.99%',
#  '143.179',
#  '711,627',
#  '677,428',
#  '972,782',
#  '4.57%',
#  '131.083',
#  '672,018',
#  '621,301',
#  '969,604',
#  '4.56%',
#  '130.791',
#  '663,258',
#  '612,828',
#  '906,672',
#  '4.29%',
#  '122.977',
#  '561,801',
#  '522,009',
#  '-',
#  '4.14%',
#  '118.733',
#  '-',
#  '559,412',
#  '856,112',
#  '4.10%',
#  '117.703',
#  '634,408',
#  '590,569',
#  '831,610',
#  '3.89%',
#  '111.519',
#  '572,240',
#  '531,085',
#  '611,804',
#  '2.81%',
#  '80.562',
#  '414,977',
#  '375,651',
#  '574,760',
#  '2.79%',
#  '79.957',
#  '418,868',
# ...

# %%
GSDP1=tag[0:161:5]

# %%
Share=tag[1:162:5]

# %%
GDP=tag[2:163:5]

# %%
for i in driver.find_elements_by_xpath('//td[@class="data sorting_1"]'):
    GSDP2.append(i.text)
GSDP2=GSDP2[:33]

# %%
data=pd.DataFrame()
data["Rank"]=Rank
data["States"]=State
data["GSDP1"]=GSDP1
data["GSDP2"]=GSDP2
data["Share"]=Share
data["GDP"]=GDP
data
# Out:
#    Rank                     States      GSDP1      GSDP2   Share      GDP
# 0     1                Maharashtra          -  2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu  1,845,853  1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh  1,687,818  1,584,764   8.39%  240.726
# 3     4                    Gujarat          -  1,502,899   7.96%  228.290
# 4     5                  Karnataka  1,631,977  1,493,127   7.91%  226.806
# 5     6                West Bengal  1,253,832  1,089,898   5.77%  165.556
# 6     7                  Rajasthan  1,020,989    942,586   4.99%  143.179
# 7     8             Andhra Pradesh    972,782    862,957   4.57%  131.083
# 8     9                  Telangana    969,604    861,031   4.56%  130.791
# 9    10             Madhya Pradesh    906,672    809,592   4.29%  122.977
# 10   11                     Kerala          -    781,653   4.14%  118.733
# 11   12                      Delhi    856,112    774,870   4.10%  117.703
# ...

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
#
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get(" https://github.com/")

# %%
explore_tag=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
explore_tag.click()

# %%
trending_tag=driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
trending_tag.click()

# %%
#create empty list
Repository=[]
Repository_description=[]
Contributors=[]
Language=[]

# %%
for i in driver.find_elements_by_xpath('//span[@class="text-normal"]'):
    Repository.append(i.text.replace('/'," "))
Repository
# Out:
# ['almerico  ',
#  'iaddis  ',
#  'AppFlowy-IO  ',
#  'cat-milk  ',
#  'HashLips  ',
#  'freqtrade  ',
#  'erkexzcx  ',
#  'AlexTrushkovsky  ',
#  'MHProDev  ',
#  'ajax-lives  ',
#  'Developer-Y  ',
#  'palahsu  ',
#  'curated-intel  ',
#  'techchipnet  ',
#  'ytdl-org  ',
#  'github  ',
#  'cyprosecurity  ',
#  'LimerBoy  ',
#  'RunaCapital  ',
#  'jseidl  ',
#  'Luzhnuy  ',
#  'hwdsl2  ',
#  'vinta  ',
#  'uberhalit  ',
#  'sindresorhus  ']

# %%
for i in driver.find_elements_by_xpath('//p[@class="col-9 color-fg-muted my-1 pr-4"]'):
    Repository_description.append(i.text.replace('/'," "))
Repository_description
# Out:
# ['bombardier',
#  'Transistor level NES simulation',
#  'AppFlowy is an open-source alternative to Notion. You are in charge of your data and customizations. Built with Flutter and Rust.',
#  'Anime Girls Holding Programming Books',
#  'HashLips Art Engine is a tool used to create multiple different instances of artworks based on provided layers.',
#  'Free, open source crypto trading bot',
#  'DOS application to stop pro-Russian aggression websites. Support Ukraine!',
#  'DDoS Russian websites to help Ukraine to win this hybrid war',
#  'Best DDoS Attack Script Python3, Cyber Attack With 40 Methods',
#  'Volunteer DoS tool via HTML + JS',
#  'List of Computer Science courses with video lectures.',
#  'DDos Ripper a Distributable Denied-of-Service (DDOS) attack server that cuts off targets or surrounding infrastructure in a flood of Internet traffic',
# ...

# %%
for i in driver.find_elements_by_xpath('//span[@class="d-inline-block ml-0 mr-3"]'):
    Language.append(i.text)
Language
# Out:
# ['HCL',
#  'JavaScript',
#  'Rust',
#  'JavaScript',
#  'Python',
#  'Go',
#  'Python',
#  'Python',
#  'HTML',
#  'Python',
#  'HTML',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Shell',
#  'Python',
#  'C#']

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.
#
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get("https:/www.billboard.com/")

# %%
hot_100=driver.find_element_by_xpath('//a[@class="c-link  lrv-a-unstyle-link lrv-u-color-brand-primary:hover lrv-a-hover-effect lrv-u-whitespace-nowrap lrv-u-color-grey-dark"]')
hot_100.click()

# %%
#create empty list
Song=[]
Artist=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
for i in driver.find_elements_by_xpath('//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]'):
    Artist.append(i.text)
len(Artist)
# Out:
# 99

# %%
rank=[]
for i in driver.find_elements_by_xpath('//span[@class="c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max"]'):
    rank.append(i.text)
len(rank)
# Out:
# 594

# %%
Last_week_rank=rank[0::6]
len(Last_week_rank)
# Out:
# 99

# %%
Peak_rank=rank[1::6]
len(Peak_rank)
# Out:
# 99

# %%
Weeks_on_board=rank[2::6]
len(Weeks_on_board)
# Out:
# 99

# %%
for i in driver.find_elements_by_xpath('//h3[@class="c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only"]'):
    Song.append(i.text)
len(Song)
# Out:
# 99

# %%
data=pd.DataFrame()
data["Songs"]=Song
data["Artist"]=Artist
data["Last_week_rank"]=Last_week_rank
data["Peak_rank"]=Peak_rank
data["Weeks_on_board"]=Weeks_on_board
data
# Out:
#                               Songs                         Artist  \
# 0                        Heat Waves                  Glass Animals
# 1                        Easy On Me                          Adele
# 2                           abcdefu                          GAYLE
# 3                              Stay  The Kid LAROI & Justin Bieber
# 4                     Super Gremlin                    Kodak Black
# ..                              ...                            ...
# 94  All Too Well (Taylor's Version)                   Taylor Swift
# 95       Come Back As A Country Boy                  Blake Shelton
# 96                             Iffy                    Chris Brown
# 97                       Home Sweet              Russell Dickerson
# 98                         Too Easy                 Gunna & Future
#
#    Last_week_rank Peak_rank Weeks_on_board
# 0               4         2             57
# 1               3         1             19
# ...

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get("https://www.naukri.com/naukri-dot-com-recruiters")

# %%
search_bar=driver.find_element_by_xpath('//input[@class="sugInp"]')
search_bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="29210cff612400f255f87d5dce61a642", element="b56dd281-c3f1-42ed-a03d-4d616c9ff911")>

# %%
search_bar.send_keys("Data Science")

# %%
search_button=driver.find_element_by_xpath('//button[@class="fl qsbSrch blueBtn"]')
search_button.click()

# %%
Name=[]
for i in driver.find_elements_by_xpath('//span[@class="fl ellipsis"]'):
    Name.append(i.text)
len(Name)
# Out:
# 50

# %%
Company=[]
for i in driver.find_elements_by_xpath('//a[@class="ellipsis"][2]'):
    Company.append(i.text)
len(Company)
# Out:
# 50

# %%
Skills=[]
for i in driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]'):
    Skills.append(i.text)
len(Skills)
# Out:
# 50

# %%
Designation=[]
for i in driver.find_elements_by_xpath('//span[@class="ellipsis clr"]'):
    Designation.append(i.text)
len(Designation)
# Out:
# 50

# %%
data=pd.DataFrame()
data["Name"]=Name
data["Designation"]=Designation
data["Skills"]=Skills
data["Company"]=Company
data.head()
# Out:
#                        Name        Designation  \
# 0              Aakash Harit         HR Manager
# 1      shravan Kumar Gaddam  Company Recruiter
# 2  MARSIAN Technologies LLP         Company HR
# 3              Anik Agrawal  Company Recruiter
# 4              subhas patel        Founder CEO
#
#                                               Skills  \
# 0  Classic ASP Developer, Internet Marketing Prof...
# 1  .Net, Java, Data Science, Linux Administration...
# 2  Data Science, Artificial Intelligence, Machine...
# 3  Mean Stack, javascript, angularjs, mongodb, We...
# 4  Hadoop, Spark, Digital Strategy, Data Architec...
#
#                                  Company
# 0                   Data Science Network
# 1          Shore Infotech India Pvt. Ltd
# 2               MARSIAN Technologies LLP
# 3  Enerlytics Software Solutions Pvt Ltd
# 4                        LibraryXProject

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
#create list
Book=[]
Author=[]
Volumnes_sold=[]
Publisher=[]
Genre=[]

# %%
tag=driver.find_elements_by_xpath('//td[@class="left"]')
len(tag)
# Out:
# 500

# %%
Tag=[]
for i in tag:
   Tag.append(i.text)
Tag
# Out:
# ['1',
#  'Da Vinci Code,The',
#  'Brown, Dan',
#  '5,094,805',
#  'Transworld',
#  '2',
#  'Harry Potter and the Deathly Hallows',
#  'Rowling, J.K.',
#  '4,475,152',
#  'Bloomsbury',
#  '3',
#  "Harry Potter and the Philosopher's Stone",
#  'Rowling, J.K.',
#  '4,200,654',
#  'Bloomsbury',
#  '4',
#  'Harry Potter and the Order of the Phoenix',
#  'Rowling, J.K.',
#  '4,179,479',
#  'Bloomsbury',
#  '5',
#  'Fifty Shades of Grey',
#  'James, E. L.',
#  '3,758,936',
#  'Random House',
#  '6',
#  'Harry Potter and the Goblet of Fire',
#  'Rowling, J.K.',
#  '3,583,215',
#  'Bloomsbury',
#  '7',
#  'Harry Potter and the Chamber of Secrets',
#  'Rowling, J.K.',
#  '3,484,047',
#  'Bloomsbury',
#  '8',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Rowling, J.K.',
#  '3,377,906',
#  'Bloomsbury',
#  '9',
#  'Angels and Demons',
#  'Brown, Dan',
#  '3,193,946',
#  'Transworld',
#  '10',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Rowling, J.K.',
# ...

# %%
Book=Tag[1::5]
len(Book)
# Out:
# 100

# %%
Author=Tag[2::5]
len(Author)
# Out:
# 100

# %%
Volumes_sold=Tag[3::5]
len(Volumes_sold)
# Out:
# 100

# %%
Publisher=Tag[4::5]
len(Publisher)
# Out:
# 100

# %%
genre_tag=driver.find_elements_by_xpath('//td[@class="last left"]')
for i in genre_tag:
    Genre.append(i.text)
len(Genre)
# Out:
# 100

# %%
data=pd.DataFrame()
data["Book_name"]=Book
data["Author_name"]=Author
data["Volumnes_sold"]=Volumes_sold
data["Publisher"]=Publisher
data["Genre"]=Genre
data
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumnes_sold        Publisher                        Genre
# ...

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get(" https://www.imdb.com/list/ls095964455/")

# %%
#create list
Name=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]

# %%
name_tag=driver.find_elements_by_xpath('//h3[@class="lister-item-header"]')
len(name_tag)
# Out:
# 100

# %%
for i in name_tag:
    Name.append(i.text)
Name
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016– )',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017– )',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014– )',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011–2019)',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016–2021)',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
genre_tag=driver.find_elements_by_xpath('//span[@class="genre"]')
len(genre_tag)
# Out:
# 100

# %%
for i in genre_tag:
    Genre.append(i.text)
Genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
time_tag=driver.find_elements_by_xpath('//span[@class="runtime"]')
len(time_tag)
# Out:
# 100

# %%
for i in time_tag:
    Run_time.append(i.text)
Run_time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
ratings_tag=driver.find_elements_by_xpath('//div[@class="ipl-rating-widget"]')
len(ratings_tag)
# Out:
# 100

# %%
for i in ratings_tag:
    Ratings.append(i.text)
Ratings
# Out:
# ['9.2\nRate',
#  '8.7\nRate',
#  '8.1\nRate',
#  '7.5\nRate',
#  '7.6\nRate',
#  '8\nRate',
#  '6.7\nRate',
#  '7.5\nRate',
#  '7.6\nRate',
#  '7.5\nRate',
#  '8.2\nRate',
#  '8.1\nRate',
#  '8.8\nRate',
#  '9.1\nRate',
#  '8.5\nRate',
#  '7.4\nRate',
#  '7.7\nRate',
#  '8\nRate',
#  '9.4\nRate',
#  '8.1\nRate',
#  '8.4\nRate',
#  '8.3\nRate',
#  '8.1\nRate',
#  '7.6\nRate',
#  '8.6\nRate',
#  '7.7\nRate',
#  '8.8\nRate',
#  '8.6\nRate',
#  '8.8\nRate',
#  '8.3\nRate',
#  '8.4\nRate',
#  '8.5\nRate',
#  '8.2\nRate',
#  '6.2\nRate',
#  '7.4\nRate',
#  '8.3\nRate',
#  '7.8\nRate',
#  '8.6\nRate',
#  '7.9\nRate',
#  '8.4\nRate',
#  '9.2\nRate',
#  '6.6\nRate',
#  '8.1\nRate',
#  '8.7\nRate',
#  '8.8\nRate',
#  '7.4\nRate',
#  '8.3\nRate',
#  '8.5\nRate',
#  '7.7\nRate',
#  '7.5\nRate',
#  '7.7\nRate',
#  '8.6\nRate',
#  '6.9\nRate',
#  '8.1\nRate',
#  '8\nRate',
#  '8.3\nRate',
#  '8.8\nRate',
#  '8.7\nRate',
#  '6.7\nRate',
#  '8.3\nRate',
#  '8.3\nRate',
#  '7.4\nRate',
# ...

# %%
vote_tag=driver.find_elements_by_xpath('//p[@class="text-muted text-small"]')
len(vote_tag)
# Out:
# 300

# %%
for i in vote_tag:
    Votes.append(i.text)
Votes=Votes[2::3]
Votes
# Out:
# ['Votes: 1,955,706',
#  'Votes: 965,609',
#  'Votes: 931,518',
#  'Votes: 278,927',
#  'Votes: 239,110',
#  'Votes: 293,018',
#  'Votes: 137,112',
#  'Votes: 288,165',
#  'Votes: 333,174',
#  'Votes: 423,403',
#  'Votes: 447,260',
#  'Votes: 773,885',
#  'Votes: 505,779',
#  'Votes: 880,103',
#  'Votes: 494,613',
#  'Votes: 161,510',
#  'Votes: 307,136',
#  'Votes: 304,978',
#  'Votes: 1,672,353',
#  'Votes: 304,226',
#  'Votes: 423,217',
#  'Votes: 511,769',
#  'Votes: 144,529',
#  'Votes: 140,651',
#  'Votes: 390,639',
#  'Votes: 218,683',
#  'Votes: 398,547',
#  'Votes: 409,712',
#  'Votes: 936,831',
#  'Votes: 654,531',
#  'Votes: 390,555',
#  'Votes: 368,657',
#  'Votes: 129,734',
#  'Votes: 120,928',
#  'Votes: 167,596',
#  'Votes: 150,060',
#  'Votes: 222,998',
#  'Votes: 467,908',
#  'Votes: 206,645',
#  'Votes: 402,734',
#  'Votes: 462,155',
#  'Votes: 59,994',
#  'Votes: 173,384',
#  'Votes: 490,543',
#  'Votes: 346,056',
#  'Votes: 68,951',
#  'Votes: 251,346',
# ...

# %%
data=pd.DataFrame()
data["Name"]=Name
data["Genre"]=Genre
data["Ratings"]=Ratings
data["Run_time"]=Run_time
data["Votes"]=Votes
data
# Out:
#                                               Name                     Genre  \
# 0                   1. Game of Thrones (2011–2019)  Action, Adventure, Drama
# 1                      2. Stranger Things (2016– )    Drama, Fantasy, Horror
# 2                  3. The Walking Dead (2010–2022)   Drama, Horror, Thriller
# 3                    4. 13 Reasons Why (2017–2020)  Drama, Mystery, Thriller
# 4                           5. The 100 (2014–2020)    Drama, Mystery, Sci-Fi
# ..                                             ...                       ...
# 95                           96. Reign (2013–2017)            Drama, Fantasy
# 96  97. A Series of Unfortunate Events (2017–2019)  Adventure, Comedy, Drama
# 97                  98. Criminal Minds (2005–2020)     Crime, Drama, Mystery
# 98           99. Scream: The TV Series (2015–2019)      Comedy, Crime, Drama
# 99          100. The Haunting of Hill House (2018)    Drama, Horror, Mystery
#
#       Ratings Run_time             Votes
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
#
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
#import all required libraries
import selenium
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
driver.get(" https://archive.ics.uci.edu/")

# %%
#create list
Name=[]
Data_type=[]
Task=[]
Attribute_type=[]
Instances=[]
Attribute=[]
Year=[]

# %%
all_datasets=driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/span/b/a')
all_datasets.click()

# %%
tag=[]
for i in driver.find_elements_by_xpath('//p[@class="normal"]'):
    tag.append(i.text)
tag
# Out:
# ['Classification (466)\nRegression (151)\nClustering (121)\nOther (56)',
#  'Categorical (38)\nNumerical (422)\nMixed (55)',
#  'Multivariate (480)\nUnivariate (30)\nSequential (59)\nTime-Series (126)\nText (69)\nDomain-Theory (23)\nOther (21)',
#  'Life Sciences (147)\nPhysical Sciences (57)\nCS / Engineering (234)\nSocial Sciences (41)\nBusiness (45)\nGame (12)\nOther (81)',
#  'Less than 10 (166)\n10 to 100 (279)\nGreater than 100 (110)',
#  'Less than 100 (38)\n100 to 1000 (210)\nGreater than 1000 (339)',
#  'Matrix (439)\nNon-Matrix (183)',
#  'Table View  List View',
#  'Abalone',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '4177 ',
#  '8 ',
#  '1995 ',
#  'Adult',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer ',
#  '48842 ',
#  '14 ',
#  '1996 ',
#  'Annealing',
#  'Multivariate ',
#  'Classification ',
#  'Categorical, Integer, Real ',
#  '798 ',
#  '38 ',
#  ' ',
#  'Anonymous Microsoft Web Data',
#  ' ',
# ...

# %%
Name=tag[8:4362:7]
#Name

# %%
Data_types=tag[9:4363:7]
#Data_types

# %%
Task=tag[10:4364:7]
#Task

# %%
Attribute_type=tag[11:4365:7]
#Attribute_type

# %%
Instances=tag[12:4366:7]
#Instances

# %%
Attributes=tag[13:4367:7]
#Attributes

# %%
Year=tag[14:4368:7]
#Year

# %%
data=pd.DataFrame()
data["Name"]=Name
data["Attribute_type"]=Attribute_type
data["Data_types"]=Data_types
data["Task"]=Task
data["Instances"]=Instances
data["Attributes"]=Attributes
data["Year"]=Year

data
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                   Attribute_type                  Data_types  \
# 0    Categorical, Integer, Real                Multivariate
# 1          Categorical, Integer                Multivariate
# 2    Categorical, Integer, Real                Multivariate
# 3                   Categorical
# ...
